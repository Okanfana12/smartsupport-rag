# %%
# Cellule 1 — Setup
import sys
sys.path.append('/workspaces/smartsupport-rag')

from src.ingestion.loader import load_file, load_directory

# Test CSV
docs = load_file('data/csv_files/historique_tickets_2026.csv')
print(f"Nombre de documents : {len(docs)}")
print(f"\nContenu du 1er doc :\n{docs[0].page_content[:300]}")
print(f"\nMétadonnées : {docs[0].metadata}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       1 # Cellule 1 — Setup
#       2 import sys
#       3 sys.path.append('/workspaces/smartsupport-rag')
#       4
# ----> 5 from src.ingestion.loader import load_file, load_directory
#       6
#       7 # Test CSV
#       8 docs = load_file('data/csv_files/historique_tickets_2026.csv')
#
# File /workspaces/smartsupport-rag/src/ingestion/loader.py:21
#      18 from pathlib import Path
#      19 from typing import List
# ---> 21 from langchain_core.documents import Document
#      22 from langchain_community.document_loaders import (
#      23     PyPDFLoader,           # PDF  — extrait texte page par page
#      24     Docx2txtLoader,        # DOCX — extrait texte des paragraphes Word
#    (...)     30     UnstructuredEmailLoader,       # EML  — extrait sujet + corps
#      31 )
# ...
